# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # SELECT and SELECT WHERE
# © ExploreAI Academy

# %% [markdown]
# In this walk-through we demonstrate how to get data out of a table using the SELECT statement.
# We also show how to filter data using the where clause.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use SELECT and SELECT DISTINCT to select columns.
# - How to use WHERE to filter data based on a condition.
# - Save results sets as new tables.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:password@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# Suppose we want to find out which country had the lowest percentage of people with access to managed drinking water services in 2020.

# %% [markdown]
# ### 1. Exploring the database
#
# Use the `SELECT` statement to display all the columns from the `Access_to_Basic_Services` table. This will help us get a feel for the data we're working with.

# %%
# %%sql
# # Add your code here
# SELECT * FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('18.755666'), Decimal('171.08'), Decimal('2699700.00'), Decimal('4.89')),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2015, Decimal('89.67'), Decimal('96.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2016, Decimal('90.33'), Decimal('96.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2017, Decimal('91.00'), Decimal('97.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2018, Decimal('91.33'), Decimal('97.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2019, Decimal('91.67'), Decimal('97.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2020, Decimal('92.67'), Decimal('97.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2015, Decimal('80.33'), Decimal('95.00'), Decimal('8.524063'), Decimal('8.27'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2016, Decimal('81.33'), Decimal('95.33'), Decimal('8.725318'), Decimal('6.99'), Decimal('138790.00'), Decimal('6.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2017, Decimal('82.33'), Decimal('95.67'), Decimal('8.925525'), Decimal('7.54'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2018, Decimal('83.33'), Decimal('95.67'), Decimal('9.128132'), Decimal('7.77'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2019, Decimal('85.00'), Decimal('96.33'), Decimal('9.337003'), Decimal('8.30'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('9.543207'), Decimal('8.13'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2015, Decimal('97.67'), Decimal('97.33'), Decimal('5.766431'), Decimal('35.80'), Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('5.868561'), Decimal('36.17'), Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2017, Decimal('98.67'), Decimal('98.00'), Decimal('5.968383'), Decimal('37.93'), Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2018, Decimal('99.33'), Decimal('98.67'), Decimal('6.065066'), Decimal('40.77'), Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('6.158420'), Decimal('45.23'), Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', '
00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2015, Decimal('96.33'), Decimal('70.67'), Decimal('0.743274'), Decimal('2.00'), Decimal('38117.00'), Decimal('2.45')),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2016, Decimal('97.00'), Decimal('71.67'), Decimal('0.749761'), Decimal('2.16'), Decimal('38144.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2017, Decimal('97.33'), Decimal('73.33'), Decimal('0.756121'), Decimal('2.45'), Decimal('38144.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2018, Decimal('97.33'), Decimal('74.33'), Decimal('0.762096'), Decimal('2.45'), Decimal('38140.00'), Decimal('3.35')),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2019, Decimal('97.33'), Decimal('75.00'), Decimal('0.767459'), Decimal('2.54'), Decimal('38140.00'), Decimal('2.72')),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), Decimal('0.772506'), Decimal('2.33'), Decimal('38140.00'), Decimal('5.03')),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2015, Decimal('89.00'), Decimal('59.33'), Decimal('1322.866505'), Decimal('2103.59'), Decimal('2973190.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2016, Decimal('89.33'), Decimal('62.00'), Decimal('1338.636340'), Decimal('2294.80'), Decimal('2973190.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2017, Decimal('90.00'), Decimal('64.33'), Decimal('1354.195680'), Decimal('2651.47'), Decimal('2973190.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2018, Decimal('90.33'), Decimal('67.00'), Decimal('1369.003306'), Decimal('2702.93'), Decimal('2973190.00'), Decimal('7.65')),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2019, Decimal('90.67'), Decimal('69.67'), Decimal('1383.112050'), Decimal('2831.55'), Decimal('2973190.00'), Decimal('6.51')),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2020, Decimal('91.00'), Decimal('72.33'), Decimal('1396.387127'), Decimal('2667.69'), Decimal('2973190.00'), Decimal('7.86')),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2015, Decimal('95.67'), Decimal('86.00'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2016, Decimal('96.00'), Decimal('87.00'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2017, Decimal('96.33'), Decimal('87.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2018, Decimal('96.33'), Decimal('88.00'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2019, Decimal('96.33'), Decimal('88.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2020, Decimal('96.67'), Decimal('88.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Maldives', 2015, Decimal('99.00'), Decimal('94.67'), Decimal('0.435582'), Decimal('4.11'), Decimal('300.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Maldives', 2016, Decimal('99.00'), Decimal('95.33'), Decimal('0.454252'), Decimal('4.38'), Decimal('300.00'), Decimal('5.77')),
#  ('Central and Southern Asia', 'Southern Asia', 'Maldives', 2017, Decimal('99.33'), Decimal('96.33'), Decimal('0.472442'), Decimal('4.75'), Decimal('300.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', '
 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.063911'), Decimal('7.42'), Decimal('54.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Bermuda', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.063893'), Decimal('6.89'), Decimal('54.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2015, Decimal('99.00'), Decimal('99.00'), Decimal('35.702908'), Decimal('1556.51'), Decimal('8965590.00'), Decimal('6.91')),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2016, Decimal('99.00'), Decimal('99.00'), Decimal('36.109487'), Decimal('1527.99'), Decimal('8965590.00'), Decimal('7.00')),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2017, Decimal('99.00'), Decimal('99.00'), Decimal('36.545236'), Decimal('1649.27'), Decimal('8965590.00'), Decimal('6.34')),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2018, Decimal('99.00'), Decimal('99.00'), Decimal('37.065084'), Decimal('1725.33'), Decimal('8965590.00'), Decimal('5.83')),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2019, Decimal('99.00'), Decimal('99.00'), Decimal('37.601230'), Decimal('1742.02'), Decimal('8965590.00'), Decimal('5.66')),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2020, Decimal('99.00'), Decimal('99.00'), Decimal('38.037204'), Decimal('1645.42'), Decimal('8965590.00'), Decimal('9.46')),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('0.056114'), Decimal('2.50'), Decimal('410450.00'), Decimal('9.10')),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('0.056186'), Decimal('2.71'), Decimal('410450.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('0.056171'), Decimal('2.85'), Decimal('410450.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('0.056023'), Decimal('3.06'), Decimal('410450.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.056225'), Decimal('2.99'), Decimal('410450.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.056367'), Decimal('3.08'), Decimal('410450.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2015, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2016, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2017, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2018, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2019, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2020, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2015, Decimal('99.00'), Decimal('99.67'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2016, Decimal('99.33'), Decimal('99.67'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2017, Decimal('99.67'), Decimal('99.67'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2018, Decimal('99.67'), Decimal('99.67'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2019, Decimal('99.67'), Decimal('99.67'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2020, Decimal('100.00'), Decimal('99.67'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Anguilla', 2015, Decimal('97.00'), Decimal('97.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', '
00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea-Bissau', 2016, Decimal('60.33'), Decimal('16.33'), Decimal('1.834552'), Decimal('1.18'), Decimal('28120.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea-Bissau', 2017, Decimal('60.00'), Decimal('17.00'), Decimal('1.879826'), Decimal('1.35'), Decimal('28120.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea-Bissau', 2018, Decimal('60.00'), Decimal('18.00'), Decimal('1.924955'), Decimal('1.50'), Decimal('28120.00'), Decimal('3.20')),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea-Bissau', 2019, Decimal('60.00'), Decimal('18.33'), Decimal('1.970457'), Decimal('1.44'), Decimal('28120.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828'), Decimal('1.43'), Decimal('28120.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2015, Decimal('72.67'), Decimal('17.00'), Decimal('4.612329'), Decimal('3.23'), Decimal('96320.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2016, Decimal('73.00'), Decimal('17.33'), Decimal('4.706097'), Decimal('3.40'), Decimal('96320.00'), Decimal('3.08')),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2017, Decimal('74.00'), Decimal('17.33'), Decimal('4.796631'), Decimal('3.39'), Decimal('96320.00'), Decimal('5.95')),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2018, Decimal('74.00'), Decimal('17.67'), Decimal('4.889391'), Decimal('3.42'), Decimal('96320.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2019, Decimal('75.00'), Decimal('17.67'), Decimal('4.985289'), Decimal('3.32'), Decimal('96320.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584'), Decimal('3.04'), Decimal('96320.00'), None),
#  ...]

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
# # Add your code here
#
# SELECT * FROM Access_to_Basic_Services LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('18.755666'), Decimal('171.08'), Decimal('2699700.00'), Decimal('4.89')),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2015, Decimal('89.67'), Decimal('96.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2016, Decimal('90.33'), Decimal('96.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2017, Decimal('91.00'), Decimal('97.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2018, Decimal('91.33'), Decimal('97.33'), None, None, None, None)]

# %% [markdown]
# ### 2. Unique country names
# Extract a list of unique country names in the database.

# %%
# %%sql
# # Add your code here
#
# SELECT DISTINCT Country_name FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Kazakhstan',),
#  ('Kyrgyzstan',),
#  ('Tajikistan',),
#  ('Turkmenistan',),
#  ('Uzbekistan',),
#  ('Afghanistan',),
#  ('Bangladesh',),
#  ('Bhutan',),
#  ('India',),
#  ('Iran (Islamic Republic of)',),
#  ('Maldives',),
#  ('Nepal',),
#  ('Pakistan',),
#  ('Sri Lanka',),
#  ('China',),
#  ("Democratic People's Republic of Korea",),
#  ('Japan',),
#  ('Mongolia',),
#  ('Republic of Korea',),
#  ('Brunei Darussalam',),
#  ('Cambodia',),
#  ('Indonesia',),
#  ("Lao People's Democratic Republic",),
#  ('Malaysia',),
#  ('Myanmar',),
#  ('Philippines',),
#  ('Singapore',),
#  ('Thailand',),
#  ('Timor-Leste',),
#  ('Viet Nam',),
#  ('Bermuda',),
#  ('Canada',),
#  ('Greenland',),
#  ('Saint Pierre and Miquelon',),
#  ('United States of America',),
#  ('Anguilla',),
#  ('Antigua and Barbuda',),
#  ('Aruba',),
#  ('Bahamas',),
#  ('Barbados',),
#  ('British Virgin Islands',),
#  ('Cayman Islands',),
#  ('Cuba',),
#  ('Curaçao',),
#  ('Dominica',),
#  ('Dominican Republic',),
#  ('Grenada',),
#  ('Guadeloupe',),
#  ('Haiti',),
#  ('Jamaica',),
#  ('Martinique',),
#  ('Montserrat',),
#  ('Puerto Rico',),
#  ('Saint Barthélemy',),
#  ('Saint Kitts and Nevis',),
#  ('Saint Lucia',),
#  ('Saint Martin (French Part)',),
#  ('Saint Vincent and the Grenadines',),
#  ('Sint Maarten (Dutch part)',),
#  ('Trinidad and Tobago',),
#  ('Turks and Caicos Islands',),
#  ('United States Virgin Islands',),
#  ('Belize',),
#  ('Costa Rica',),
#  ('El Salvador',),
#  ('Guatemala',),
#  ('Honduras',),
#  ('Mexico',),
#  ('Nicaragua',),
#  ('Panama',),
#  ('Argentina',),
#  ('Bolivia (Plurinational State of)',),
#  ('Brazil',),
#  ('Chile',),
#  ('Colombia',),
#  ('Ecuador',),
#  ('Falkland Islands (Malvinas)',),
#  ('French Guiana',),
#  ('Guyana',),
#  ('Paraguay',),
#  ('Peru',),
#  ('Suriname',),
#  ('Uruguay',),
#  ('Venezuela (Bolivarian Republic of)',),
#  ('Algeria',),
#  ('Egypt',),
#  ('Libya',),
#  ('Morocco',),
#  ('Sudan',),
#  ('Tunisia',),
#  ('Armenia',),
#  ('Azerbaijan',),
#  ('Bahrain',),
#  ('Cyprus',),
#  ('Georgia',),
#  ('Iraq',),
#  ('Israel',),
#  ('Jordan',),
#  ('Kuwait',),
#  ('Lebanon',),
#  ('Oman',),
#  ('Qatar',),
#  ('Saudi Arabia',),
#  ('State of Palestine',),
#  ('Syrian Arab Republic',),
#  ('Türkiye',),
#  ('United Arab Emirates',),
#  ('Yemen',),
#  ('Australia',),
#  ('New Zealand',),
#  ('Fiji',),
#  ('New Caledonia',),
#  ('Papua New Guinea',),
#  ('Solomon Islands',),
#  ('Vanuatu',),
#  ('Guam',),
#  ('Kiribati',),
#  ('Marshall Islands',),
#  ('Micronesia (Federated States of)',),
#  ('Nauru',),
#  ('Northern Mariana Islands',),
#  ('Palau',),
#  ('American Samoa',),
#  ('Cook Islands',),
#  ('French Polynesia',),
#  ('Niue',),
#  ('Samoa',),
#  ('Tokelau',),
#  ('Tonga',),
#  ('Tuvalu',),
#  ('Wallis and Futuna Islands',),
#  ('Burundi',),
#  ('Comoros',),
#  ('Djibouti',),
#  ('Eritrea',),
#  ('Ethiopia',),
#  ('Kenya',),
#  ('Madagascar',),
#  ('Malawi',),
#  ('Mauritius',),
#  ('Mayotte',),
#  ('Mozambique',),
#  ('Rwanda',),
#  ('Réunion',),
#  ('Seychelles',),
#  ('Somalia',),
#  ('South Sudan',),
#  ('Uganda',),
#  ('United Republic of Tanzania',),
#  ('Zambia',),
#  ('Zimbabwe',),
#  ('Angola',),
#  ('Cameroon',),
#  ('Central African Republic',),
#  ('Chad',),
#  ('Congo',),
#  ('Democratic Republic of the Congo',),
#  ('Equatorial Guinea',),
#  ('Gabon',),
#  ('Sao Tome and Principe',),
#  ('Botswana',),
#  ('Eswatini',),
#  ('Lesotho',),
#  ('Namibia',),
#  ('South Africa',),
#  ('Benin',),
#  ('Burkina Faso',),
#  ('Cabo Verde',),
#  ("Côte d'Ivoire",),
#  ('Gambia',),
#  ('Ghana',),
#  ('Guinea',),
#  ('Guinea-Bissau',),
#  ('Liberia',),
#  ('Mali',),
#  ('Mauritania',),
#  ('Niger',),
#  ('Nigeria',),
#  ('Saint Helena',),
#  ('Senegal',),
#  ('Sierra Leone',),
#  ('Togo',)]

# %% [markdown]
# Create a new table called `Country_list` and save the unique country names into this table.

# %%
# %%sql
# # Add your code here
# CREATE TABLE Country_list (
#     `name` varchar(255)
# );
# INSERT INTO  Country_list(name)
# SELECT DISTINCT Country_name as name FROM Access_to_Basic_Services;
# SELECT * FROM Country_list;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# 182 rows affected.
# 182 rows affected.
# [('Kazakhstan',),
#  ('Kyrgyzstan',),
#  ('Tajikistan',),
#  ('Turkmenistan',),
#  ('Uzbekistan',),
#  ('Afghanistan',),
#  ('Bangladesh',),
#  ('Bhutan',),
#  ('India',),
#  ('Iran (Islamic Republic of)',),
#  ('Maldives',),
#  ('Nepal',),
#  ('Pakistan',),
#  ('Sri Lanka',),
#  ('China',),
#  ("Democratic People's Republic of Korea",),
#  ('Japan',),
#  ('Mongolia',),
#  ('Republic of Korea',),
#  ('Brunei Darussalam',),
#  ('Cambodia',),
#  ('Indonesia',),
#  ("Lao People's Democratic Republic",),
#  ('Malaysia',),
#  ('Myanmar',),
#  ('Philippines',),
#  ('Singapore',),
#  ('Thailand',),
#  ('Timor-Leste',),
#  ('Viet Nam',),
#  ('Bermuda',),
#  ('Canada',),
#  ('Greenland',),
#  ('Saint Pierre and Miquelon',),
#  ('United States of America',),
#  ('Anguilla',),
#  ('Antigua and Barbuda',),
#  ('Aruba',),
#  ('Bahamas',),
#  ('Barbados',),
#  ('British Virgin Islands',),
#  ('Cayman Islands',),
#  ('Cuba',),
#  ('Curaçao',),
#  ('Dominica',),
#  ('Dominican Republic',),
#  ('Grenada',),
#  ('Guadeloupe',),
#  ('Haiti',),
#  ('Jamaica',),
#  ('Martinique',),
#  ('Montserrat',),
#  ('Puerto Rico',),
#  ('Saint Barthélemy',),
#  ('Saint Kitts and Nevis',),
#  ('Saint Lucia',),
#  ('Saint Martin (French Part)',),
#  ('Saint Vincent and the Grenadines',),
#  ('Sint Maarten (Dutch part)',),
#  ('Trinidad and Tobago',),
#  ('Turks and Caicos Islands',),
#  ('United States Virgin Islands',),
#  ('Belize',),
#  ('Costa Rica',),
#  ('El Salvador',),
#  ('Guatemala',),
#  ('Honduras',),
#  ('Mexico',),
#  ('Nicaragua',),
#  ('Panama',),
#  ('Argentina',),
#  ('Bolivia (Plurinational State of)',),
#  ('Brazil',),
#  ('Chile',),
#  ('Colombia',),
#  ('Ecuador',),
#  ('Falkland Islands (Malvinas)',),
#  ('French Guiana',),
#  ('Guyana',),
#  ('Paraguay',),
#  ('Peru',),
#  ('Suriname',),
#  ('Uruguay',),
#  ('Venezuela (Bolivarian Republic of)',),
#  ('Algeria',),
#  ('Egypt',),
#  ('Libya',),
#  ('Morocco',),
#  ('Sudan',),
#  ('Tunisia',),
#  ('Armenia',),
#  ('Azerbaijan',),
#  ('Bahrain',),
#  ('Cyprus',),
#  ('Georgia',),
#  ('Iraq',),
#  ('Israel',),
#  ('Jordan',),
#  ('Kuwait',),
#  ('Lebanon',),
#  ('Oman',),
#  ('Qatar',),
#  ('Saudi Arabia',),
#  ('State of Palestine',),
#  ('Syrian Arab Republic',),
#  ('Türkiye',),
#  ('United Arab Emirates',),
#  ('Yemen',),
#  ('Australia',),
#  ('New Zealand',),
#  ('Fiji',),
#  ('New Caledonia',),
#  ('Papua New Guinea',),
#  ('Solomon Islands',),
#  ('Vanuatu',),
#  ('Guam',),
#  ('Kiribati',),
#  ('Marshall Islands',),
#  ('Micronesia (Federated States of)',),
#  ('Nauru',),
#  ('Northern Mariana Islands',),
#  ('Palau',),
#  ('American Samoa',),
#  ('Cook Islands',),
#  ('French Polynesia',),
#  ('Niue',),
#  ('Samoa',),
#  ('Tokelau',),
#  ('Tonga',),
#  ('Tuvalu',),
#  ('Wallis and Futuna Islands',),
#  ('Burundi',),
#  ('Comoros',),
#  ('Djibouti',),
#  ('Eritrea',),
#  ('Ethiopia',),
#  ('Kenya',),
#  ('Madagascar',),
#  ('Malawi',),
#  ('Mauritius',),
#  ('Mayotte',),
#  ('Mozambique',),
#  ('Rwanda',),
#  ('Réunion',),
#  ('Seychelles',),
#  ('Somalia',),
#  ('South Sudan',),
#  ('Uganda',),
#  ('United Republic of Tanzania',),
#  ('Zambia',),
#  ('Zimbabwe',),
#  ('Angola',),
#  ('Cameroon',),
#  ('Central African Republic',),
#  ('Chad',),
#  ('Congo',),
#  ('Democratic Republic of the Congo',),
#  ('Equatorial Guinea',),
#  ('Gabon',),
#  ('Sao Tome and Principe',),
#  ('Botswana',),
#  ('Eswatini',),
#  ('Lesotho',),
#  ('Namibia',),
#  ('South Africa',),
#  ('Benin',),
#  ('Burkina Faso',),
#  ('Cabo Verde',),
#  ("Côte d'Ivoire",),
#  ('Gambia',),
#  ('Ghana',),
#  ('Guinea',),
#  ('Guinea-Bissau',),
#  ('Liberia',),
#  ('Mali',),
#  ('Mauritania',),
#  ('Niger',),
#  ('Nigeria',),
#  ('Saint Helena',),
#  ('Senegal',),
#  ('Sierra Leone',),
#  ('Togo',)]

# %% [markdown]
# ### 3. Selecting specific fields
#
# Select the `country_name`, `time_period`, and `pct_managed_drinking_water_services` fields from the `Access_to_Basic_Services` table.

# %%
# %%sql
# # Add your code here
# SELECT country_name, time_period, pct_managed_drinking_water_services FROM Access_to_Basic_Services
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Kazakhstan', 2015, Decimal('94.67')),
#  ('Kazakhstan', 2016, Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('95.00')),
#  ('Kazakhstan', 2018, Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('95.00')),
#  ('Kyrgyzstan', 2015, Decimal('89.67')),
#  ('Kyrgyzstan', 2016, Decimal('90.33')),
#  ('Kyrgyzstan', 2017, Decimal('91.00')),
#  ('Kyrgyzstan', 2018, Decimal('91.33')),
#  ('Kyrgyzstan', 2019, Decimal('91.67')),
#  ('Kyrgyzstan', 2020, Decimal('92.67')),
#  ('Tajikistan', 2015, Decimal('80.33')),
#  ('Tajikistan', 2016, Decimal('81.33')),
#  ('Tajikistan', 2017, Decimal('82.33')),
#  ('Tajikistan', 2018, Decimal('83.33')),
#  ('Tajikistan', 2019, Decimal('85.00')),
#  ('Tajikistan', 2020, Decimal('85.00')),
#  ('Turkmenistan', 2015, Decimal('97.67')),
#  ('Turkmenistan', 2016, Decimal('98.00'))]

# %% [markdown]
# Rename the `pct_managed_drinking_water_services` field to `pct_access_to_water` in your query results.

# %%
# %%sql
# # Add your code here
# SELECT
#     country_name,
#     time_period,
#     pct_managed_drinking_water_services as pct_access_to_water
# FROM
#     Access_to_Basic_Services
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Kazakhstan', 2015, Decimal('94.67')),
#  ('Kazakhstan', 2016, Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('95.00')),
#  ('Kazakhstan', 2018, Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('95.00')),
#  ('Kyrgyzstan', 2015, Decimal('89.67')),
#  ('Kyrgyzstan', 2016, Decimal('90.33')),
#  ('Kyrgyzstan', 2017, Decimal('91.00')),
#  ('Kyrgyzstan', 2018, Decimal('91.33')),
#  ('Kyrgyzstan', 2019, Decimal('91.67')),
#  ('Kyrgyzstan', 2020, Decimal('92.67')),
#  ('Tajikistan', 2015, Decimal('80.33')),
#  ('Tajikistan', 2016, Decimal('81.33')),
#  ('Tajikistan', 2017, Decimal('82.33')),
#  ('Tajikistan', 2018, Decimal('83.33')),
#  ('Tajikistan', 2019, Decimal('85.00')),
#  ('Tajikistan', 2020, Decimal('85.00')),
#  ('Turkmenistan', 2015, Decimal('97.67')),
#  ('Turkmenistan', 2016, Decimal('98.00'))]

# %% [markdown]
# ### 4. Filtering and sorting data
#
# Modify your query to only display data for the year `2020`.

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# WHERE
#     time_period = 2020
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('18.755666'), Decimal('171.08'), Decimal('2699700.00'), Decimal('4.89')),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2020, Decimal('92.67'), Decimal('97.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('9.543207'), Decimal('8.13'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('6.250438'), None, Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Uzbekistan', 2020, Decimal('98.00'), Decimal('100.00'), Decimal('34.232050'), Decimal('59.89'), Decimal('440650.00'), Decimal('5.29')),
#  ('Central and Southern Asia', 'Southern Asia', 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00'), Decimal('38.972230'), Decimal('20.14'), Decimal('652230.00'), Decimal('11.71')),
#  ('Central and Southern Asia', 'Southern Asia', 'Bangladesh', 2020, Decimal('97.67'), Decimal('54.00'), Decimal('167.420951'), Decimal('373.90'), Decimal('130170.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), Decimal('0.772506'), Decimal('2.33'), Decimal('38140.00'), Decimal('5.03')),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2020, Decimal('91.00'), Decimal('72.33'), Decimal('1396.387127'), Decimal('2667.69'), Decimal('2973190.00'), Decimal('7.86')),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2020, Decimal('96.67'), Decimal('88.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Maldives', 2020, Decimal('99.67'), Decimal('99.33'), Decimal('0.514438'), Decimal('3.75'), Decimal('300.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Nepal', 2020, Decimal('90.00'), Decimal('76.67'), Decimal('29.348627'), Decimal('33.43'), Decimal('143350.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Pakistan', 2020, Decimal('90.67'), Decimal('70.00'), Decimal('227.196741'), Decimal('300.43'), Decimal('770880.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Sri Lanka', 2020, Decimal('94.33'), Decimal('93.67'), Decimal('21.919000'), Decimal('85.35'), Decimal('61860.00'), Decimal('5.36')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'China', 2020, Decimal('93.67'), Decimal('91.67'), Decimal('1411.100000'), Decimal('14687.67'), Decimal('9424702.90'), Decimal('5.61')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', "Democratic People's Republic of Korea", 2020, Decimal('93.33'), Decimal('83.33'), None, None, None, None),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'Japan', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('126.261000'), Decimal('5040.11'), Decimal('364500.00'), Decimal('2.81')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'Mongolia', 2020, Decimal('81.00'), Decimal('65.00'), Decimal('3.294335'), Decimal('13.31'), Decimal('1557506.80'), Decimal('6.59')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'Republic of Korea', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Brunei Darussalam', 2020, Decimal('100.00'), None, Decimal('0.441725'), Decimal('12.01'), Decimal('5270.00'), Decimal('7.41'))]

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
# # Add your code here
#
# SELECT
#     country_name,
#     time_period,
#     pct_managed_drinking_water_services as pct_access_to_water
# FROM
#     Access_to_Basic_Services
# WHERE
#     time_period = 2020
# ORDER BY pct_access_to_water #Since we cannot sort like we did in the MySQL GUI, we have to use SQL. Just add your code before this line, and this line will order your results.
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Central African Republic', 2020, Decimal('38.33')),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67')),
#  ('South Sudan', 2020, Decimal('48.33')),
#  ('Angola', 2020, Decimal('52.33')),
#  ('Chad', 2020, Decimal('52.67')),
#  ('Burkina Faso', 2020, Decimal('53.33')),
#  ('Madagascar', 2020, Decimal('56.33')),
#  ('Papua New Guinea', 2020, Decimal('56.67')),
#  ('Somalia', 2020, Decimal('57.33')),
#  ('Niger', 2020, Decimal('57.33'))]

# %% [markdown]
# And there is the answer at the top:

# %%
#Answer:

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Exploring the database
#
# Use the `SELECT` statement to display all the columns from the `Access_to_Basic_Services` table. This will help us get a feel for the data we're working with.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     united_nations.Access_to_Basic_Services
# LIMIT 30;

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     united_nations.Access_to_Basic_Services
# LIMIT 10;

# %% [markdown]
# ### 2. Unique country names
# Extract a list of unique country names in the database.

# %%
# %%sql
#
# SELECT DISTINCT
#     Country_name
# FROM
#     united_nations.Access_to_Basic_Services
#     LIMIT 20;

# %% [markdown]
# Create a new table called `Country_list` and save the unique country names into this table.

# %%
# %%sql
#
# CREATE TABLE Country_list(Country VARCHAR(255));
# INSERT INTO Country_list(Country)
# SELECT DISTINCT
#     Country_name
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# ### 3. Selecting specific fields
#
# Select the `country_name`, `time_period`, and `pct_managed_drinking_water_services` fields from the `Access_to_Basic_Services` table.

# %%
# %%sql
#
# SELECT
#     country_name,
#     time_period,
#     pct_managed_drinking_water_services
# FROM
#     united_nations.Access_to_Basic_Services
# LIMIT 20;

# %% [markdown]
# Rename the `pct_managed_drinking_water_services` field to `pct_access_to_water` in your query results.

# %%
# %%sql
#
# SELECT
#     country_name,
#     time_period,
#     pct_managed_drinking_water_services AS pct_access_to_water
# FROM
#     united_nations.Access_to_Basic_Services
# LIMIT 20

# %% [markdown]
# ### 4. Filtering and sorting data
#
# Modify your query to only display data for the year 2020.

# %%
# %%sql
#
# SELECT
#     country_name,
#     time_period,
#     pct_managed_drinking_water_services AS pct_access_to_water
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Time_period = 2020
# LIMIT 100;

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
#
# SELECT
#     country_name,
#     time_period,
#     pct_managed_drinking_water_services AS pct_access_to_water
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Time_period = 2020
# ORDER BY pct_access_to_water
# LIMIT 10;

# %% [markdown]
# ## Summary
# Congratulations! You have used SQL commands to filter and sort data to answer a specific question. Please review your results and think about what other questions could be answered with this data.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
